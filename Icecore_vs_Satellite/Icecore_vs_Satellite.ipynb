# %% [markdown]
# # Temprature effect on Ice core

# %% [markdown]
# On polar regions such Greenland, everytime that it snows, the snow accumulates on top of previous snow. After several years the snow gets compacted and preserves the environmental conditions of the past. One of the most important features that affects snow accumulation is temperature. In this study, I aim to see the effect of temperature on snow layers.

# %% [markdown]
# To do so, I need data from snow columns (ice core data) and temperature data from satellite. Schaller et al. have been to northern parts of Greenland and they have collected several samples of ice cores (4 meter of snow) and they took X-ray image of it. The X-ray image can tell us about the density of snow layers, and we know that these 4 meters of snow is almost equal to 4 years. Thus, I am trying to see the effect of temperature on the density of icecore during these years to check the correlation and interpretation of signal.

# %% [markdown]
# link to ice core data: https://doi.pangaea.de/10.1594/PANGAEA.867873

# %% [markdown]
# link to paper for more description of the ice core project:https://tc.copernicus.org/articles/10/1991/2016/

# %% [markdown]
# Next I need the temperature distriution of the 4 years that I found with help of CVL with following title

# %% [markdown]
# Multilayer Greenland Ice Surface Temperature, Surface Albedo, and Water Vapor from MODIS
# Earth Science Data and Information System (ESDIS) Project, ESDIS
# Datacenter: NASA National Snow and Ice Data Center Distributed Active Archive Center
# Collection: ADC, GCW
# Metadata identifier: MODGRNLD

# %% [markdown]
# Also there are some obsticles for downloading the data that is dicussed here:

# %% [markdown]
# https://github.com/CryosphereVirtualLab/public-notebooks/issues/13

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from scipy import interpolate
import seaborn as sns
import tempfile
import requests
import numpy as np
import netCDF4 as nc
import os
import earthaccess
import glob
# Setup
# %matplotlib inline
import matplotlib
params = {'font.size'     : 14,
          'figure.figsize':(15.0, 8.0),
          'lines.linewidth': 2.,
          'lines.markersize': 15,}
matplotlib.rcParams.update(params)
sns.set()
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %% [markdown]
# # Step 1, Ice core data

# %% [markdown]
# Getting the Ice core data from Pangaea then averaging and sorting to pandas dataframe. In this part, having the pangaea url is necessary. This is the link to the ice core data. It has columns that are describing the density, Lon and Lat, and time of pulling out the ice cores.
# This function gets the data from the data base and makes a temporary directory, then the data (tab delimited) will be tranformed to a Pandas dataframe.

# %%
def get_icecore_data():
    # url to data file
    data_url = 'https://doi.pangaea.de/10.1594/PANGAEA.867873?format=textfile'

    # create temporary directory
    with tempfile.TemporaryDirectory() as tmpdirname:

        fpath = os.path.join(tmpdirname, 'N2E_density.tab')

        # create a request link to the file
        r = requests.get(data_url, allow_redirects=True)

        # open a file and write the linked file into it
        open(fpath, 'wb').write(r.content)

        # load the dataset on to a variable
        # it will be available after the temporary directory has been deleted agian
        with open(fpath) as inp:
            line_list = list((line for line in inp))
            data = list(line.split('\t') for line in line_list[38:])
            for i in range (len (data)):
                data[i][-1] = float(data[i][-1][:-2])
                        
            columns = list(line_list[37].split('\t'))
            columns[-1] = columns[-1][:-1]
            df = pd.DataFrame(data, columns=columns)
    return df

# %% [markdown]
# There are several ice cores collected from different locations as given in the ice core data, but we need an average of density.
# An average density is less affected by the local noise such as wind. The following function is averaging the density of the cores that are comming from different Lats.

# %%
# thsi function returns the icecore density (average) from 18 collected samples from Greenland
#https://doi.org/10.5194/tc-10-1991-2016

def icecore_density(icecore_data):    
    lats = icecore_data['Latitude'].unique()
    checker = 0
    for lat in lats:
        print ('Averaging for Latitude ',lat, 'Done')
        if checker == 0:
            density = icecore_data[icecore_data['Latitude'] == lat ]['Density [g/cm**3]'].to_numpy()
            checker = 1
        else:
            _new = icecore_data[icecore_data['Latitude'] == lat ]['Density [g/cm**3]'].to_numpy()

            if len(density) >= len(_new):
                density = density[:len(_new)] + _new
            else:
                density = density + _new[:len(density)]
    return density/len(lats)

# %%
icecore_data = get_icecore_data()
ice_density = icecore_density(icecore_data)
# Out:
# Averaging for Latitude  77.44433 Done
# Averaging for Latitude  77.36690 Done
# Averaging for Latitude  77.25429 Done
# Averaging for Latitude  77.12010 Done
# Averaging for Latitude  76.98195 Done
# Averaging for Latitude  76.84788 Done
# Averaging for Latitude  76.71337 Done
# Averaging for Latitude  76.52426 Done
# Averaging for Latitude  76.40034 Done
# Averaging for Latitude  76.32535 Done
# Averaging for Latitude  76.24889 Done
# Averaging for Latitude  76.17770 Done
# Averaging for Latitude  76.10455 Done
# Averaging for Latitude  76.01559 Done
# Averaging for Latitude  75.93539 Done
# Averaging for Latitude  75.85845 Done
# Averaging for Latitude  75.70614 Done
# Averaging for Latitude  75.62934 Done

# %% [markdown]
# On the bove, averaged ice cores density is done by their Lat

# %% [markdown]
# # Step2, Temperature data from NSIDC

# %% [markdown]
# Downloading, processing and sorting temperature data from NSIDC. At first we need to log in then find granuls of data, filter them and download it.

# %% [markdown]
# This is an interactive cridential input section, so please use your own user and pass for plug in to NSIDC

# %%
# put your cridentials (https://urs.earthdata.nasa.gov/)
auth = earthaccess.login(strategy="interactive")
# Out:
# Enter your Earthdata Login username: faramarz.bagherzadeh
# Enter your Earthdata password: ········
# You're now authenticated with NASA Earthdata Login
# Using token with expiration date: 03/29/2023

# %% [markdown]
# When you are looged in then, the weather data (temperature data) from the NASA satellite products can be downloaded as follow:
# In case you look for another data, make sure you have the correct concept_id

# %%
#Getting granules of data
earthaccess.login(strategy="environment")
granules = earthaccess.search_data(
    concept_id="C1597320047-NSIDC_ECS",
    bounding_box=(-51.06, 75.6, -35.9, 77.4),
    cloud_hosted=True,
    downloadable = True,
    temporal=("2011-05", "2015-05"),
    count=100000
)
# Out:
# We are already authenticated with NASA EDL
# Granules found: 32617

# %% [markdown]
# There are many granuls of data to download, but we only need the daily data, so to filter it out the following code is implemented. Reffering to https://github.com/CryosphereVirtualLab/public-notebooks/issues/13

# %%
# filtering the granules, we need only daily data 
daily_granules = []
i = 1
for gr in granules[:]:
    if 'daily' in str(gr):
        i += 1
        daily_granules.append(gr)
print ('found {} number of daily files'.format(i))
# Out:
# found 1463 number of daily files

# %%
#downloading the selected granules in local path
earthaccess.download(daily_granules[:], local_path="./modis_data")
# Out:
#  Getting 1462 granules, approx download size: 24.29 GB
# QUEUEING TASKS | :   0%|          | 0/1462 [00:00<?, ?it/s]
# File MODGRNLD.2011121.daily.v01.1.nc already downloaded
# File MODGRNLD.2011122.daily.v01.1.nc already downloaded
# File MODGRNLD.2011123.daily.v01.1.nc already downloaded
# File MODGRNLD.2011124.daily.v01.1.nc already downloaded
# PROCESSING TASKS | :   0%|          | 0/1462 [00:00<?, ?it/s]
# Error while downloading the file MODGRNLD.2011137.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.05.17/MODGRNLD.2011137.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011138.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.05.18/MODGRNLD.2011138.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011139.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.05.19/MODGRNLD.2011139.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011140.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.05.20/MODGRNLD.2011140.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011141.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.05.21/MODGRNLD.2011141.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011143.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.05.23/MODGRNLD.2011143.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011142.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.05.22/MODGRNLD.2011142.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011144.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.05.24/MODGRNLD.2011144.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011145.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.05.25/MODGRNLD.2011145.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011146.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011147.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.05.27/MODGRNLD.2011147.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.05.26/MODGRNLD.2011146.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011148.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.05.28/MODGRNLD.2011148.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011150.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.05.30/MODGRNLD.2011150.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011149.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.05.29/MODGRNLD.2011149.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011151.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.05.31/MODGRNLD.2011151.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011152.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011153.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.01/MODGRNLD.2011152.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.02/MODGRNLD.2011153.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011154.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.03/MODGRNLD.2011154.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011156.daily.v01.1.ncError while downloading the file MODGRNLD.2011155.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.04/MODGRNLD.2011155.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.05/MODGRNLD.2011156.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011157.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.06/MODGRNLD.2011157.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011159.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011158.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.08/MODGRNLD.2011159.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.07/MODGRNLD.2011158.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011160.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.09/MODGRNLD.2011160.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011162.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.11/MODGRNLD.2011162.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011164.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.13/MODGRNLD.2011164.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011161.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.10/MODGRNLD.2011161.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011165.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.14/MODGRNLD.2011165.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011166.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.15/MODGRNLD.2011166.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011168.daily.v01.1.ncError while downloading the file MODGRNLD.2011163.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.17/MODGRNLD.2011168.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.12/MODGRNLD.2011163.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011170.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011169.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.18/MODGRNLD.2011169.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.19/MODGRNLD.2011170.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011171.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.20/MODGRNLD.2011171.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011172.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.21/MODGRNLD.2011172.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011173.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011174.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.22/MODGRNLD.2011173.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.23/MODGRNLD.2011174.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011175.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.24/MODGRNLD.2011175.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011177.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.26/MODGRNLD.2011177.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011178.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.27/MODGRNLD.2011178.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011179.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.28/MODGRNLD.2011179.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011180.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.29/MODGRNLD.2011180.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011182.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011181.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.01/MODGRNLD.2011182.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.06.30/MODGRNLD.2011181.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011184.daily.v01.1.ncError while downloading the file MODGRNLD.2011186.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011185.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.03/MODGRNLD.2011184.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.05/MODGRNLD.2011186.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.04/MODGRNLD.2011185.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011183.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.02/MODGRNLD.2011183.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011189.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011190.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.08/MODGRNLD.2011189.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.09/MODGRNLD.2011190.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011188.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011187.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.06/MODGRNLD.2011187.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.07/MODGRNLD.2011188.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011194.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.13/MODGRNLD.2011194.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011192.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.11/MODGRNLD.2011192.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011191.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.10/MODGRNLD.2011191.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011193.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.12/MODGRNLD.2011193.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011198.daily.v01.1.ncError while downloading the file MODGRNLD.2011196.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.15/MODGRNLD.2011196.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.17/MODGRNLD.2011198.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011197.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.16/MODGRNLD.2011197.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011195.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.14/MODGRNLD.2011195.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011199.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.18/MODGRNLD.2011199.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011202.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011201.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.21/MODGRNLD.2011202.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.20/MODGRNLD.2011201.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011200.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.19/MODGRNLD.2011200.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011203.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.22/MODGRNLD.2011203.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011206.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011204.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011205.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.25/MODGRNLD.2011206.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.24/MODGRNLD.2011205.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.23/MODGRNLD.2011204.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011207.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.26/MODGRNLD.2011207.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011209.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.28/MODGRNLD.2011209.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011208.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011210.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.27/MODGRNLD.2011208.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.29/MODGRNLD.2011210.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011211.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011213.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011212.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.30/MODGRNLD.2011211.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.08.01/MODGRNLD.2011213.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.07.31/MODGRNLD.2011212.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011214.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.08.02/MODGRNLD.2011214.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011217.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.08.05/MODGRNLD.2011217.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011215.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011216.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011218.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.08.04/MODGRNLD.2011216.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.08.06/MODGRNLD.2011218.daily.v01.1.nc
#
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2011.08.03/MODGRNLD.2011215.daily.v01.1.nc
#
# Error while downloading the file MODGRNLD.2011222.daily.v01.1.nc
# Error while downloading the file MODGRNLD.2011220.daily.v01.1.nc
# Traceback (most recent call last):
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\earthaccess\store.py", line 498, in _download_file
#     r.raise_for_status()
#   File "D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\requests\models.py", line 960, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# ...
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 503 Server Error: Service Unavailable for url: https://n5eil01u.ecs.nsidc.org/DP2/MOST/MODGRNLD.001/2015.04.30/MODGRNLD.2015120.daily.v01.1.nc
# COLLECTING RESULTS | :   0%|          | 0/1462 [00:00<?, ?it/s]
# ['MODGRNLD.2011121.daily.v01.1.nc',
#  'MODGRNLD.2011122.daily.v01.1.nc',
#  'MODGRNLD.2011123.daily.v01.1.nc',
#  'MODGRNLD.2011124.daily.v01.1.nc',
#  'MODGRNLD.2011125.daily.v01.1.nc',
#  'MODGRNLD.2011126.daily.v01.1.nc',
#  'MODGRNLD.2011127.daily.v01.1.nc',
#  'MODGRNLD.2011128.daily.v01.1.nc',
#  'MODGRNLD.2011129.daily.v01.1.nc',
#  'MODGRNLD.2011130.daily.v01.1.nc',
#  'MODGRNLD.2011131.daily.v01.1.nc',
#  'MODGRNLD.2011132.daily.v01.1.nc',
#  'MODGRNLD.2011133.daily.v01.1.nc',
#  'MODGRNLD.2011134.daily.v01.1.nc',
#  'MODGRNLD.2011135.daily.v01.1.nc',
#  'MODGRNLD.2011136.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2011167.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2011176.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2011244.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2011270.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2011310.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2011354.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2012006.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2012149.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  'MODGRNLD.2012152.daily.v01.1.nc',
#  'MODGRNLD.2012153.daily.v01.1.nc',
#  'MODGRNLD.2012154.daily.v01.1.nc',
#  'MODGRNLD.2012155.daily.v01.1.nc',
#  'MODGRNLD.2012156.daily.v01.1.nc',
#  'MODGRNLD.2012157.daily.v01.1.nc',
#  'MODGRNLD.2012158.daily.v01.1.nc',
#  'MODGRNLD.2012159.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2012167.daily.v01.1.nc',
#  'MODGRNLD.2012168.daily.v01.1.nc',
#  'MODGRNLD.2012169.daily.v01.1.nc',
#  'MODGRNLD.2012170.daily.v01.1.nc',
#  'MODGRNLD.2012171.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2012188.daily.v01.1.nc',
#  'MODGRNLD.2012189.daily.v01.1.nc',
#  'MODGRNLD.2012190.daily.v01.1.nc',
#  'MODGRNLD.2012191.daily.v01.1.nc',
#  'MODGRNLD.2012192.daily.v01.1.nc',
#  'MODGRNLD.2012193.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2012201.daily.v01.1.nc',
#  'MODGRNLD.2012202.daily.v01.1.nc',
#  Exception(),
#  'MODGRNLD.2012204.daily.v01.1.nc',
#  'MODGRNLD.2012205.daily.v01.1.nc',
#  'MODGRNLD.2012206.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2012236.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2013009.daily.v01.1.nc',
#  'MODGRNLD.2013010.daily.v01.1.nc',
#  'MODGRNLD.2013011.daily.v01.1.nc',
#  'MODGRNLD.2013012.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2013053.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2013087.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2013150.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2013191.daily.v01.1.nc',
#  'MODGRNLD.2013192.daily.v01.1.nc',
#  'MODGRNLD.2013193.daily.v01.1.nc',
#  'MODGRNLD.2013194.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2013198.daily.v01.1.nc',
#  'MODGRNLD.2013199.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2013206.daily.v01.1.nc',
#  'MODGRNLD.2013207.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  'MODGRNLD.2013210.daily.v01.1.nc',
#  'MODGRNLD.2013211.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2013231.daily.v01.1.nc',
#  'MODGRNLD.2013232.daily.v01.1.nc',
#  'MODGRNLD.2013233.daily.v01.1.nc',
#  'MODGRNLD.2013234.daily.v01.1.nc',
#  'MODGRNLD.2013235.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2013255.daily.v01.1.nc',
#  'MODGRNLD.2013256.daily.v01.1.nc',
#  'MODGRNLD.2013257.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  'MODGRNLD.2013316.daily.v01.1.nc',
#  'MODGRNLD.2013317.daily.v01.1.nc',
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  Exception(),
#  ...]

# %% [markdown]
# # Processing the data granules

# %% [markdown]
# Now that we have the data granuls, we need to do pre processing them and turn it to a pandas data frame. To do so, we need to read each file with Glob library, then catching the calendar-date of data, and then putting daily avereged data to a pandas table under the related calendar-date tag.

# %%
def find_date(ds):
    # This functions reads the data_date
    date = None
    for var in ds.variables.values():
        data_date = var.data_date
        assert date == None or data_date == date , 'Date Missmatch in data package for day {}'.format(data_date)
        date = data_date
    return date

# %%
def get_data(ds):
    #This function returns a Pandas dataframe from the daily average values of each feature
    df = pd.DataFrame()
    df ['Date'] = [find_date(ds)]
    df['Ice_Surface_Temperature_Mean'] = [np.mean(ds['Ice_Surface_Temperature_Mean'][0, :, :])]
    df['Ice_Surface_Temperature_Melt_NoMelt'] = [np.mean(ds['Ice_Surface_Temperature_Melt_NoMelt'][0, :, :])]
    df['Albedo'] = [np.mean(ds['Albedo'][0, :, :])]
    df['Water_Vapor_Near_Infrared_Mean'] = [np.mean(ds['Water_Vapor_Near_Infrared_Mean'][0, :, :])]
    df['NSwaths_and_Hour_Tracker'] = [np.mean(ds['NSwaths_and_Hour_Tracker'][0, :, :])]
    return df

# %%
path = "./modis_data/*.nc"
files = glob.glob(path)
print ('There are {} [.nc] files'.format(len(files)))
# Out:
# There are 110 [.nc] files

# %% [markdown]
# This part creats the pandas dataframe from the data granuls with the help of two above functions.

# %%
#Creating a pandas data frame from granule data
output = get_data(nc.Dataset(files[0]))

for file in files[1:]:
    new_df = get_data(nc.Dataset(file))
    output = pd.concat([output, new_df], ignore_index=True,axis=0)

satellite_data = output
temp = satellite_data['Ice_Surface_Temperature_Mean'].to_numpy()

# %%
print (ice_density.shape)
print (temp.shape)
# Out:
# (12466,)
# (110,)

# %% [markdown]
# # Step3, Interpolation

# %% [markdown]
# We need interpolation to have same amount of records for satellite data and icecore data, also to see both signals in one graph with proper scale we need to normalize them

# %%
N = len(temp)
xmin, xmax = 0., len(temp)
xi = np.linspace(xmin, xmax, N)
yi = temp

plt.plot(xi,yi, 'o', label = "Available points")
plt.grid()
plt.xlabel("Record")
plt.ylabel("Temperature (degree celcius)")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
x = np.linspace(xmin, xmax, ice_density.shape[0])
interp = interpolate.interp1d(xi, yi, kind = "linear")
y_linear = interp(x)

new_temp = y_linear.copy()

plt.plot(xi,yi, 'o', label = " Available points")
plt.plot(x, y_linear, "-", label = "Linear interpolation")
plt.grid()
plt.xlabel("Record")
plt.ylabel("Temperature (degree celcius)")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# now the icecore data and satellite data have the smae amount of rows

# %%
print(new_temp.shape)
print()
# Out:
# (12466,)

# %% [markdown]
# # Step4, Analysis

# %% [markdown]
# Now that we have all the data lined up, we can start analysis both in quantitative and qualitative. Here first we are getting the statistical descriptions of each dataset, then checking the data distribution, and person correlatoin, and finally checking the signal allignments.

# %%
combined_data = pd.DataFrame()
combined_data['ice_temperature'] = new_temp
combined_data['ice_density'] = ice_density

# %%
combined_data.describe()
# Out:
#        ice_temperature   ice_density
# count     12466.000000  12466.000000
# mean        174.163227      0.324717
# std          16.909300      0.020921
# min         126.355720      0.263278
# 25%         161.263453      0.313000
# 50%         172.265486      0.324000
# 75%         183.609111      0.339056
# max         231.634545      0.389944

# %%
# for comparing two datasets we need to scale them down 
scaler = MinMaxScaler()
scaler.fit(combined_data)
normdata = pd.DataFrame(scaler.transform(combined_data.values), index=combined_data.index, columns=combined_data.columns)
# Out:
# D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
normdata.describe()
# Out:
#        ice_temperature   ice_density
# count     12466.000000  12466.000000
# mean          0.454104      0.485046
# std           0.160614      0.165166
# min           0.000000      0.000000
# 25%           0.331574      0.392544
# 50%           0.436078      0.479386
# 75%           0.543826      0.598246
# max           1.000000      1.000000

# %% [markdown]
# temperature data is more diverse has higher variance than the ice core density data.

# %%
sns.set_style("white")
ax = sns.distplot(normdata.ice_temperature, color='blue', label='Ice temperatur')
ax = sns.distplot(normdata.ice_density, color='red', label = 'Ice density')
plt.ylabel('Frequency')
plt.xlabel('Normalized ice density')
plt.rcParams.update({'font.size': 14})
plt.legend()
# Out:
# D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Software\Anaconda\envs\MachineLearning\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# We search for linear correlation between two distributions as follow:

# %%
#Using Pearson Correlation
plt.figure(figsize=(5,5))
cor = normdata.corr()
sns.heatmap(cor, annot=True)
plt.show()

# %% [markdown]
# Here we search for signal alignment to check for how many seasons these to signals are aligned and how they behave after that period

# %%
normdata['day'] = list(range(normdata.shape[0]))
sns.lineplot(data=normdata, x='day', y="ice_temperature", label = 'Ice temperature')
sns.lineplot(data=normdata, x='day', y="ice_density", label = 'Ice density')
plt.xlabel('Record')
plt.ylabel('Normalized ice temperature and density')
plt.legend()

# %% [markdown]
# # conclusion

# %% [markdown]
# After collecting ice core density data and sattelite temperature data (for 4 years), it is possible to normalize and compare these two data sets to see the effect of temperature on snow layers. The most technichal tools that are used in this notebook are the interpolation of two signals, normalization, histogram comparison, and Pearson correlation.
# It is observed from the above Fig that the ice density signal is getting compacted immediately after the first seasonal change. It is also showing that the overal density copaction is increasing during the given four years in such way that the signal disappears after two years comparing to the temperature signal.
